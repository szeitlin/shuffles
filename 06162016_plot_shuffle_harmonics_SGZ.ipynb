# %%
from explore_shuffle import plot_cases
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = plot_cases(20)
# Out:
#    cut_size  deck_size  shuffle_count
# 0         3          6              4
# 1         3          7              7
# 2         4          7              6
# 3         3          8              3
# 4         4          8              3

# %%
df.plot()

# %%
df2 = plot_cases(50)
# Out:
#    cut_size  deck_size  shuffle_count
# 0         3          6              4
# 1         3          7              7
# 2         4          7              6
# 3         3          8              3
# 4         4          8              3

# %%
df2.plot()

# %%
df3 = plot_cases(20)
# Out:
#    cut_size  deck_size  shuffle_count
# 0         3          6              4
# 1         3          7              7
# 2         4          7              6
# 3         3          8              3
# 4         4          8              3

# %%
df3.plot.scatter(x='cut_size', y='shuffle_count')

# %%
df3.plot.scatter(x='deck_size', y='shuffle_count')

# %%
df3.plot.bar()

# %%
df4 = plot_cases(10)
# Out:
#    cut_size  deck_size  shuffle_count
# 0         3          6              4
# 1         3          7              7
# 2         4          7              6
# 3         3          8              3
# 4         4          8              3

# %%
df4.plot.bar()
